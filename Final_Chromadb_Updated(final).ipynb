# %%
# !unzip -q data.zip

# %%
! pip install -q chromadb sentence-transformers openai clip-anytorch timm
! pip install -U -q bitsandbytes accelerate transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 74.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 33.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 67.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 98.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 786.3 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 36.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 104.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 34.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.9 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 105.0 MB/s eta 0:00:00

# %%
import torch
import clip
from PIL import Image
# from transformers import BlipProcessor, BlipForConditionalGeneration
from sentence_transformers import SentenceTransformer

# Load CLIP for image embeddings
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, clip_preprocess = clip.load("ViT-B/32", device=device)

# Load SentenceTransformer for text embeddings
# text_embed_model = SentenceTransformer("all-MiniLM-L6-v2")

# Load BLIP for image captioning (helps add more context for retrieval)
# blip_processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
# blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large").to(device)

# def get_text_embedding(text):
#     return text_embed_model.encode(text).tolist()
# def get_text_embedding(text):
#     text_tokens = clip.tokenize([text]).to(device)
#     with torch.no_grad():
#         text_embedding = clip_model.encode_text(text_tokens).cpu().numpy().flatten()
#     return text_embedding.tolist()

# def get_image_embedding(image_path):
#     image = Image.open(image_path).convert("RGB")
#     image = clip_preprocess(image).unsqueeze(0).to(device)
#     with torch.no_grad():
#         image_embedding = clip_model.encode_image(image).cpu().numpy().flatten()
#     return image_embedding.tolist()

text_image_model = SentenceTransformer("clip-ViT-B-32")
model = SentenceTransformer('distiluse-base-multilingual-cased-v2')


def get_text_embedding(text):
    return model.encode(text).tolist()


def get_image_embedding(image_path):
    image = Image.open(image_path).convert("RGB")
    return text_image_model.encode(image).tolist()

# def generate_image_caption(image_path):
#     image = Image.open(image_path).convert("RGB")
#     inputs = blip_processor(image, return_tensors="pt").to(device)
#     caption = blip_model.generate(**inputs)
#     return blip_processor.decode(caption[0], skip_special_tokens=True)
# Out:
# 100%|████████████████████████████████████████| 354M/354M [00:02<00:00, 139MiB/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.91k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.03k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/604 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.50, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# modules.json:   0%|          | 0.00/341 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/2.46k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/610 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/539M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/531 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.58M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/114 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.58M [00:00<?, ?B/s]

# %%
# len(get_text_embedding("image_10.jpeg"))

# %%
# generate_image_caption("image_10.jpeg")

# %%
# !rm -r ./chroma_db

# %%
# from chromadb.utils import embedding_functions

# class CustomEmbeddingFunction(embedding_functions.EmbeddingFunction):
#     def __call__(self, input):
#         return text_image_model.encode(input).tolist()

# %%
import chromadb

chroma_client = chromadb.PersistentClient(path="./chroma_db")
collection = chroma_client.get_or_create_collection(name="skin_diseases",)

# %%
# Insert a dummy 512D embedding to set the correct dimension
dummy_embedding = [0.0] * 512  # A vector of 512 zeros

collection.add(
    ids=["dummy_id"],
    embeddings=[dummy_embedding],  # This forces the collection to use 512D
    metadatas=[{"name": "Dummy Entry", "description": "Placeholder"}]
)

# %%
def add_skin_disease(doc_id, disease_name, symptoms, image_path):
    text_desc = f"{disease_name}: {symptoms}"
    # image_caption = generate_image_caption(image_path)  # Generate automatic caption for image

    text_embedding = get_text_embedding(text_desc)
    # print(len(text_embedding))
    # image_embedding = get_image_embedding(image_path)
    image_embedding = get_image_embedding(image_path)
    # print(len(image_embedding))

    # Combine embeddings
    final_embedding = [(x + y) / 2 for x, y in zip(text_embedding, image_embedding)]
    # print(len(final_embedding))

    metadata = {"id": doc_id, "disease": disease_name, "symptoms": symptoms, "image_path": image_path}

    collection.add(ids=[doc_id], embeddings=[final_embedding], metadatas=[metadata])

# %%
# # Example: Adding data
# add_skin_disease("eczema_002", "acne_due_to_medicine", "Red, itchy, inflamed skin", "image_9.jpeg")

# %%
import os

# %%
for disease in sorted(os.listdir("/content/data")):
    disease_images=sorted(os.listdir("/content/data/"+disease+"/images"))
    symptoms=open("/content/data/"+disease+f"/texts/{disease}_symptoms.txt").read()
    for j in range(len(disease_images)):
      add_skin_disease(f"{disease}_{j}", disease,symptoms,"/content/data/"+disease+"/images/"+disease_images[j])

# %%
collection.get(include=["embeddings"])
# Out:
# {'ids': ['dummy_id',
#   'ace_inhibitor_induced_angioedema_0',
#   'ace_inhibitor_induced_angioedema_1',
#   'acne_due_to_medicine_0',
#   'acne_due_to_medicine_1',
#   'acne_due_to_medicine_2',
#   'acne_due_to_medicine_3',
#   'acrodynia_0',
#   'actinic_prurigo_0',
#   'actinic_prurigo_1',
#   'actinic_prurigo_2',
#   'actinic_prurigo_3',
#   'acute_generalised_exanthematous_pustulosis_0',
#   'acute_generalised_exanthematous_pustulosis_1',
#   'acute_generalised_exanthematous_pustulosis_2',
#   'acute_generalised_exanthematous_pustulosis_3',
#   'acute_generalised_exanthematous_pustulosis_4',
#   'acute_generalised_exanthematous_pustulosis_5',
#   'acute_generalised_exanthematous_pustulosis_6',
#   'acute_generalised_exanthematous_pustulosis_7',
#   'acute_generalised_exanthematous_pustulosis_8',
#   'acute_generalised_exanthematous_pustulosis_9',
#   'acute_generalised_exanthematous_pustulosis_pathology_0',
#   'acute_generalised_exanthematous_pustulosis_pathology_1',
#   'acute_generalised_exanthematous_pustulosis_pathology_2',
#   'acute_generalised_exanthematous_pustulosis_pathology_3',
#   'acute_localised_exanthematous_pustulosis_0',
#   'acute_localised_exanthematous_pustulosis_1',
#   'acute_localised_exanthematous_pustulosis_2',
#   'acute_urticaria_0',
#   'acute_urticaria_1',
#   'acute_urticaria_2',
#   'acute_urticaria_3',
#   'acute_urticaria_4',
#   'acute_urticaria_5',
#   'acute_urticaria_6',
#   'adverse_cutaneous_reactions_to_drugs_0',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_0',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_1',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_2',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_3',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_4',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_5',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_6',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_7',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_8',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_9',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_10',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_11',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_12',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_13',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_14',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_15',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_16',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_17',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_18',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_19',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_20',
#   'adverse_cutaneous_reactions_to_psychotropic_drugs_21',
#   'adverse_cutaneous_reactions_to_vaccines_0',
#   'adverse_cutaneous_reactions_to_vaccines_1',
#   'adverse_cutaneous_reactions_to_vaccines_2',
#   'aeroallergens_0',
#   'aeroallergens_1',
#   'aeroallergens_2',
#   'aeroallergens_3',
#   'aeroallergens_4',
#   'aeroallergens_5',
#   'aeroallergens_6',
#   'airborne_contact_dermatitis_0',
#   'airborne_contact_dermatitis_1',
#   'airborne_contact_dermatitis_2',
#   'airborne_contact_dermatitis_3',
#   'allergic_conjunctivitis_0',
#   'allergic_contact_cheilitis_0',
#   'allergic_contact_cheilitis_1',
#   'allergic_contact_cheilitis_2',
#   'allergic_contact_cheilitis_3',
#   'allergic_contact_cheilitis_4',
#   'allergic_contact_dermatitis_0',
#   'allergic_contact_dermatitis_1',
#   'allergic_contact_dermatitis_2',
#   'allergic_contact_dermatitis_3',
#   'allergic_contact_dermatitis_in_children_0',
#   'allergic_contact_dermatitis_in_children_1',
#   'allergic_contact_dermatitis_in_children_2',
#   'allergic_contact_dermatitis_in_children_3',
#   'allergic_contact_dermatitis_in_children_4',
#   'allergic_contact_dermatitis_in_children_5',
#   'allergic_contact_dermatitis_in_children_6',
#   'allergic_contact_dermatitis_to_essential_oils_0',
#   'allergic_contact_dermatitis_to_essential_oils_1',
#   'allergic_contact_dermatitis_to_essential_oils_2',
#   'allergic_contact_dermatitis_to_essential_oils_3',
#   'allergic_contact_dermatitis_to_essential_oils_4',
#   'allergic_contact_dermatitis_to_essential_oils_5',
#   'allergic_contact_dermatitis_to_essential_oils_6',
#   'allergic_contact_dermatitis_to_isocyanate_0',
#   'allergic_contact_dermatitis_to_isocyanate_1',
#   'allergic_contact_dermatitis_to_isocyanate_2',
#   'allergic_contact_dermatitis_to_isocyanate_3',
#   'allergic_contact_dermatitis_to_isocyanate_4',
#   'allergic_contact_dermatitis_to_isocyanate_5',
#   'allergic_contact_dermatitis_to_isocyanate_6',
#   'allergies_explained_0',
#   'allergies_explained_1',
#   'allergies_explained_2',
#   'allergies_explained_3',
#   'allergies_explained_4',
#   'allergies_explained_5',
#   'allergies_explained_6',
#   'allergies_explained_7',
#   'allergies_explained_8',
#   'allergies_explained_9',
#   'allergies_explained_10',
#   'allergies_explained_11',
#   'allergies_explained_12',
#   'allergy_to_acrylate_0',
#   'allergy_to_acrylate_1',
#   'allergy_to_ammonium_persulfate_0',
#   'allergy_to_avobenzone_0',
#   'allergy_to_bacitracin_0',
#   'allergy_to_bemotrizinol_0',
#   'allergy_to_benzocaine_0',
#   'allergy_to_benzocaine_1',
#   'allergy_to_benzocaine_2',
#   'allergy_to_benzocaine_3',
#   'allergy_to_benzophenone_0',
#   'allergy_to_bisoctrizole_0',
#   'allergy_to_cinnamate_0',
#   'allergy_to_clioquinol_0',
#   'allergy_to_cobalt_0',
#   'allergy_to_cobalt_1',
#   'allergy_to_cobalt_2',
#   'allergy_to_diethylthiourea_0',
#   'allergy_to_diethylthiourea_1',
#   'allergy_to_diethylthiourea_2',
#   'allergy_to_diethylthiourea_3',
#   'allergy_to_dimethyl_fumarate_0',
#   'allergy_to_dimethyl_fumarate_1',
#   'allergy_to_dimethyl_fumarate_2',
#   'allergy_to_ecamsule_0',
#   'allergy_to_ensulizole_0',
#   'allergy_to_epoxy_resin_0',
#   'allergy_to_epoxy_resin_1',
#   'allergy_to_epoxy_resin_2',
#   'allergy_to_epoxy_resin_3',
#   'allergy_to_ethylenediamine_0',
#   'allergy_to_ethylenediamine_1',
#   'allergy_to_ethylenediamine_2',
#   'allergy_to_ethylenediamine_3',
#   'allergy_to_glyceryl_monothioglycolate_0',
#   'allergy_to_imidazolidinyl_urea_0',
#   'allergy_to_imidazolidinyl_urea_1',
#   'allergy_to_iodopropynyl_butylcarbamate_0',
#   'allergy_to_methyldibromoglutaronitrile_0',
#   'allergy_to_neomycin_0',
#   'allergy_to_neomycin_1',
#   'allergy_to_neomycin_2',
#   'allergy_to_paba_0',
#   'allergy_to_para_tertiary_butylphenol_formaldehyde_resin_0',
#   'allergy_to_para_tertiary_butylphenol_formaldehyde_resin_1',
#   'allergy_to_para_tertiary_butylphenol_formaldehyde_resin_2',
#   'allergy_to_para_tertiary_butylphenol_formaldehyde_resin_3',
#   'allergy_to_parabens_0',
#   'allergy_to_paraphenylenediamine_0',
#   'allergy_to_paraphenylenediamine_1',
#   'allergy_to_paraphenylenediamine_2',
#   'allergy_to_paraphenylenediamine_3',
#   'allergy_to_paraphenylenediamine_4',
#   'allergy_to_paraphenylenediamine_5',
#   'allergy_to_quaternium_15_0',
#   'allergy_to_quaternium_15_1',
#   'allergy_to_quaternium_15_2',
#   'allergy_to_quaternium_15_3',
#   'allergy_to_rubber_accelerators_0',
#   'allergy_to_rubber_accelerators_1',
#   'allergy_to_rubber_accelerators_2',
#   'allergy_to_rubber_accelerators_3',
#   'allergy_to_rubber_accelerators_4',
#   'allergy_to_topical_corticosteroid_0',
#   'allergy_to_topical_corticosteroid_1',
#   'allergy_to_topical_corticosteroid_2',
#   'allergy_to_topical_medications_0',
#   'allergy_to_topical_medications_1',
#   'allergy_to_topical_medications_2',
#   'allergy_to_topical_medications_3',
#   'allergy_to_topical_salicylate_0',
#   'alopecia_from_drugs_0',
#   'alopecia_from_drugs_1',
#   'alopecia_from_drugs_2',
#   'alopecia_from_drugs_3',
#   'amalgam_tattoo_0',
#   'amalgam_tattoo_1',
#   'amalgam_tattoo_2',
#   'anaphylaxis_0',
#   'anaphylaxis_1',
#   'anaphylaxis_2',
#   'anaphylaxis_3',
#   'angioedema_0',
#   'angioedema_1',
#   'angioedema_2',
#   'angioedema_3',
#   'angioedema_4',
#   'angioedema_5',
#   'angioedema_6',
#   'anticholinergic_medications_0',
#   'anticoagulants_and_antiplatelet_agents_0',
#   'antihistamines_0',
#   'aquagenic_pruritus_0',
#   'aquagenic_pruritus_1',
#   'aquagenic_urticaria_0',
#   'aquagenic_urticaria_1',
#   'aquagenic_wrinkling_of_the_palms_0',
#   'aquagenic_wrinkling_of_the_palms_1',
#   'aquagenic_wrinkling_of_the_palms_2',
#   'argyria_0',
#   'arnica_0',
#   'arnica_1',
#   'arnica_2',
#   'artichoke_0',
#   'artichoke_1',
#   'asparagus_0',
#   'asparagus_1',
#   'asparagus_2',
#   'atopy_0',
#   'atopy_1',
#   'atopy_2',
#   'atopy_3',
#   'atopy_4',
#   'atopy_5',
#   'atopy_6',
#   'atopy_patch_test_0',
#   'atopy_patch_test_1',
#   'auriculotemporal_syndrome_0',
#   'australian_box_jellyfish_stings_0',
#   'australian_box_jellyfish_stings_1',
#   'australian_box_jellyfish_stings_2',
#   'australian_box_jellyfish_stings_3',
#   'australian_box_jellyfish_stings_4',
#   'australian_box_jellyfish_stings_5',
#   'balsam_of_peru_allergy_0',
#   'bee_and_wasp_stings_0',
#   'bee_and_wasp_stings_1',
#   'bee_and_wasp_stings_2',
#   'bee_and_wasp_stings_3',
#   'bee_and_wasp_stings_4',
#   'bee_and_wasp_stings_5',
#   'bee_and_wasp_stings_6',
#   'bee_and_wasp_stings_7',
#   'bee_and_wasp_stings_8',
#   'bee_and_wasp_stings_9',
#   'bee_and_wasp_stings_10',
#   'bee_and_wasp_stings_11',
#   'bee_and_wasp_stings_12',
#   'benzalkonium_chloride_contact_dermatitis_0',
#   'benzalkonium_chloride_contact_dermatitis_1',
#   'benzalkonium_chloride_contact_dermatitis_2',
#   'beta_blockers_0',
#   'beta_blockers_1',
#   'beta_blockers_2',
#   'beta_blockers_3',
#   'beta_blockers_4',
#   'beta_blockers_5',
#   'beta_blockers_6',
#   'beta_blockers_7',
#   'beta_blockers_8',
#   'beta_blockers_9',
#   'bindii_dermatitis_0',
#   'bindii_dermatitis_1',
#   'black_henna_tattoo_reaction_0',
#   'black_henna_tattoo_reaction_1',
#   'black_henna_tattoo_reaction_2',
#   'black_henna_tattoo_reaction_3',
#   'black_henna_tattoo_reaction_4',
#   'black_henna_tattoo_reaction_5',
#   'black_henna_tattoo_reaction_6',
#   'black_henna_tattoo_reaction_7',
#   'black_henna_tattoo_reaction_8',
#   'black_henna_tattoo_reaction_9',
#   'black_henna_tattoo_reaction_10',
#   'black_henna_tattoo_reaction_11',
#   'blackwood_0',
#   'blackwood_1',
#   'blackwood_2',
#   'blackwood_3',
#   'bleaching_agents_0',
#   'bleaching_agents_1',
#   'bleaching_agents_2',
#   'bleaching_agents_3',
#   'bleaching_agents_4',
#   'bleomycin_0',
#   'bleomycin_1',
#   'blister_agents_in_chemical_warfare_0',
#   'brachioradial_pruritus_0',
#   'brachioradial_pruritus_1',
#   'brachioradial_pruritus_2',
#   'brachioradial_pruritus_3',
#   'brachioradial_pruritus_4',
#   'brachioradial_pruritus_5',
#   'brachioradial_pruritus_6',
#   'bullous_drug_eruptions_0',
#   'bullous_drug_eruptions_1',
#   'bullous_drug_eruptions_2',
#   'bullous_drug_eruptions_3',
#   'bullous_drug_eruptions_4',
#   'bullous_drug_eruptions_5',
#   'bullous_drug_eruptions_6',
#   'burning_mouth_syndrome_0',
#   'burns_from_ointments_0',
#   'burns_from_ointments_1',
#   'burns_from_ointments_2',
#   'burns_from_ointments_3',
#   'cashew_nut_0',
#   'cashew_nut_1',
#   'celery_0',
#   'celery_1',
#   'chemical_burn_0',
#   'chemical_burn_1',
#   'chemical_burn_2',
#   'chemical_burn_3',
#   'chives_0',
#   'chives_1',
#   'chloracne_madish_0',
#   'chloracne_madish_1',
#   'chloracne_madish_2',
#   'chloracne_madish_3',
#   'chloracne_madish_4',
#   'chrome_allergy_0',
#   'chrome_allergy_1',
#   'chrome_allergy_2',
#   'chronic_arsenic_poisoning_0',
#   'chronic_arsenic_poisoning_1',
#   'chronic_arsenic_poisoning_2',
#   'chronic_arsenic_poisoning_3',
#   'chronic_inducible_urticaria_0',
#   'chronic_inducible_urticaria_1',
#   'chronic_inducible_urticaria_2',
#   'chronic_inducible_urticaria_3',
#   'chronic_inducible_urticaria_4',
#   'chronic_inducible_urticaria_5',
#   'chronic_inducible_urticaria_6',
#   'chronic_inducible_urticaria_7',
#   'chronic_inducible_urticaria_8',
#   'chronic_inducible_urticaria_9',
#   'chronic_inducible_urticaria_10',
#   'chronic_spontaneous_urticaria_0',
#   'chronic_spontaneous_urticaria_1',
#   'chronic_spontaneous_urticaria_2',
#   'chronic_spontaneous_urticaria_3',
#   'chronic_spontaneous_urticaria_4',
#   'chronic_spontaneous_urticaria_5',
#   'chronic_spontaneous_urticaria_6',
#   'chronic_spontaneous_urticaria_7',
#   'chronic_spontaneous_urticaria_8',
#   'chronic_spontaneous_urticaria_9',
#   'chronic_spontaneous_urticaria_10',
#   'chronic_spontaneous_urticaria_11',
#   'chronic_spontaneous_urticaria_12',
#   'chronic_spontaneous_urticaria_13',
#   'chronic_urticaria_0',
#   'chronic_urticaria_1',
#   'chronic_urticaria_2',
#   'chronic_urticaria_3',
#   'chronic_urticaria_4',
#   'chronic_urticaria_5',
#   'chronic_urticaria_6',
#   'chrysanthemum_0',
#   'chrysanthemum_1',
#   'chrysanthemum_2',
#   'citron_0',
#   'citron_1',
#   'coconut_diethanolamide_allergy_0',
#   'cold_urticaria_0',
#   'cold_urticaria_1',
#   'cold_urticaria_2',
#   'cold_urticaria_3',
#   'cold_urticaria_4',
#   'cold_urticaria_5',
#   'cold_urticaria_6',
#   'colloid_milium_0',
#   'colloid_milium_1',
#   'colloid_milium_2',
#   'colloid_milium_3',
#   'colloid_milium_4',
#   'colloid_milium_pathology_0',
#   'colloid_milium_pathology_1',
#   'colloid_milium_pathology_2',
#   'colloid_milium_pathology_3',
#   'colloid_milium_pathology_4',
#   'colloid_milium_pathology_5',
#   'colloid_milium_pathology_6',
#   'compositae_allergy_0',
#   'compositae_allergy_1',
#   'compositae_allergy_2',
#   'compositae_allergy_3',
#   'compositae_allergy_4',
#   'compositae_allergy_5',
#   'compositae_allergy_6',
#   'compositae_allergy_7',
#   'compositae_allergy_8',
#   'compositae_allergy_9',
#   'computer_mouse_dermatitis_0',
#   'computer_mouse_dermatitis_1',
#   'computer_mouse_dermatitis_2',
#   'computer_mouse_dermatitis_3',
#   'consort_allergic_contact_dermatitis_0',
#   'consort_allergic_contact_dermatitis_1',
#   'consort_allergic_contact_dermatitis_2',
#   'consort_allergic_contact_dermatitis_3',
#   'contact_allergens_0',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_0',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_1',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_2',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_3',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_4',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_5',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_6',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_7',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_8',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_9',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_10',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_11',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_12',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_13',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_14',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_15',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_16',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_17',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_18',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_19',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_20',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_21',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_22',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_23',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_24',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_25',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_26',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_27',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_28',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_29',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_30',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_31',
#   'contact_allergic_dermatitis_of_the_arm_and_leg_images_32',
#   'contact_allergic_dermatitis_of_the_face_images_0',
#   'contact_allergic_dermatitis_of_the_face_images_1',
#   'contact_allergic_dermatitis_of_the_face_images_2',
#   'contact_allergic_dermatitis_of_the_face_images_3',
#   'contact_allergic_dermatitis_of_the_face_images_4',
#   'contact_allergic_dermatitis_of_the_face_images_5',
#   'contact_allergic_dermatitis_of_the_face_images_6',
#   'contact_allergic_dermatitis_of_the_face_images_7',
#   'contact_allergic_dermatitis_of_the_face_images_8',
#   'contact_allergic_dermatitis_of_the_face_images_9',
#   'contact_allergic_dermatitis_of_the_face_images_10',
#   'contact_allergic_dermatitis_of_the_face_images_11',
#   'contact_allergic_dermatitis_of_the_face_images_12',
#   'contact_allergic_dermatitis_of_the_face_images_13',
#   'contact_allergic_dermatitis_of_the_face_images_14',
#   'contact_allergic_dermatitis_of_the_face_images_15',
#   'contact_allergic_dermatitis_of_the_face_images_16',
#   'contact_allergic_dermatitis_of_the_face_images_17',
#   'contact_allergic_dermatitis_of_the_face_images_18',
#   'contact_allergic_dermatitis_of_the_face_images_19',
#   'contact_allergic_dermatitis_of_the_face_images_20',
#   'contact_allergic_dermatitis_of_the_face_images_21',
#   'contact_allergic_dermatitis_of_the_face_images_22',
#   'contact_allergic_dermatitis_of_the_face_images_23',
#   'contact_allergic_dermatitis_of_the_face_images_24',
#   'contact_allergic_dermatitis_of_the_face_images_25',
#   'contact_allergic_dermatitis_of_the_face_images_26',
#   'contact_allergic_dermatitis_of_the_face_images_27',
#   'contact_allergic_dermatitis_of_the_face_images_28',
#   'contact_allergic_dermatitis_of_the_face_images_29',
#   'contact_allergic_dermatitis_of_the_face_images_30',
#   'contact_allergic_dermatitis_of_the_face_images_31',
#   'contact_allergic_dermatitis_of_the_face_images_32',
#   'contact_allergic_dermatitis_of_the_face_images_33',
#   'contact_allergic_dermatitis_of_the_hand_images_0',
#   'contact_allergic_dermatitis_of_the_hand_images_1',
#   'contact_allergic_dermatitis_of_the_hand_images_2',
#   'contact_allergic_dermatitis_of_the_hand_images_3',
#   'contact_allergic_dermatitis_of_the_hand_images_4',
#   'contact_allergic_dermatitis_of_the_hand_images_5',
#   'contact_allergic_dermatitis_of_the_hand_images_6',
#   'contact_allergic_dermatitis_of_the_hand_images_7',
#   'contact_allergic_dermatitis_of_the_hand_images_8',
#   'contact_allergic_dermatitis_of_the_hand_images_9',
#   'contact_allergic_dermatitis_of_the_hand_images_10',
#   'contact_allergic_dermatitis_of_the_hand_images_11',
#   'contact_allergic_dermatitis_of_the_hand_images_12',
#   'contact_allergic_dermatitis_of_the_hand_images_13',
#   'contact_allergic_dermatitis_of_the_hand_images_14',
#   'contact_allergic_dermatitis_of_the_hand_images_15',
#   'contact_allergic_dermatitis_of_the_hand_images_16',
#   'contact_allergic_dermatitis_of_the_hand_images_17',
#   'contact_allergic_dermatitis_of_the_hand_images_18',
#   'contact_allergic_dermatitis_of_the_hand_images_19',
#   'contact_allergic_dermatitis_of_the_torso_images_0',
#   'contact_allergic_dermatitis_of_the_torso_images_1',
#   'contact_allergic_dermatitis_of_the_torso_images_2',
#   'contact_allergic_dermatitis_of_the_torso_images_3',
#   'contact_allergic_dermatitis_of_the_torso_images_4',
#   'contact_allergic_dermatitis_of_the_torso_images_5',
#   'contact_allergic_dermatitis_of_the_torso_images_6',
#   'contact_allergic_dermatitis_of_the_torso_images_7',
#   'contact_allergic_dermatitis_of_the_torso_images_8',
#   'contact_allergic_dermatitis_of_the_torso_images_9',
#   'contact_allergic_dermatitis_of_the_torso_images_10',
#   'contact_allergic_dermatitis_of_the_torso_images_11',
#   'contact_allergic_dermatitis_of_the_torso_images_12',
#   'contact_allergic_dermatitis_of_the_torso_images_13',
#   'contact_allergic_dermatitis_of_the_torso_images_14',
#   'contact_allergic_dermatitis_of_the_torso_images_15',
#   'contact_allergic_dermatitis_of_the_torso_images_16',
#   'contact_allergic_dermatitis_of_the_torso_images_17',
#   'contact_allergic_dermatitis_of_the_torso_images_18',
#   'contact_allergic_dermatitis_of_the_torso_images_19',
#   'contact_allergic_dermatitis_of_the_torso_images_20',
#   'contact_allergic_dermatitis_of_the_torso_images_21',
#   'contact_allergic_dermatitis_of_the_torso_images_22',
#   'contact_allergy_to_benzisothiazolinone_0',
#   'contact_allergy_to_bufexamac_0',
#   'contact_allergy_to_bufexamac_1',
#   'contact_allergy_to_cocamidopropyl_betaine_0',
#   'contact_allergy_to_cocamidopropyl_betaine_1',
#   'contact_allergy_to_gold_0',
#   'contact_allergy_to_gold_1',
#   'contact_allergy_to_gold_2',
#   'contact_allergy_to_gold_3',
#   'contact_allergy_to_gold_4',
#   'contact_allergy_to_lauryl_glucoside_0',
#   'contact_allergy_to_lauryl_glucoside_1',
#   'contact_allergy_to_limonene_and_linalool_0',
#   'contact_allergy_to_octyl_glucoside_0',
#   'contact_allergy_to_octylisothiazolinone_0',
#   'contact_allergy_to_preservatives_0',
#   'contact_allergy_to_propolis_0',
#   'contact_allergy_to_propolis_1',
#   'contact_allergy_to_propolis_2',
#   'contact_allergy_to_propolis_3',
#   'contact_allergy_to_propylene_glycol_0',
#   'contact_allergy_to_shellac_0',
#   'contact_allergy_to_sodium_metabisulphite_0',
#   'contact_cheilitis_and_other_reactions_involving_the_lips_of_musicians_0',
#   'contact_dermatitis_0',
#   'contact_dermatitis_1',
#   'contact_dermatitis_2',
#   'contact_dermatitis_3',
#   'contact_dermatitis_to_nitrile_0',
#   'contact_dermatitis_to_nitrile_1',
#   'contact_dermatitis_to_nitrile_2',
#   'contact_dermatitis_to_nitrile_3',
#   'contact_dermatitis_to_nitrile_4',
#   'contact_dermatitis_to_nitrile_5',
#   'contact_irritant_dermatitis_images_0',
#   'contact_irritant_dermatitis_images_1',
#   'contact_irritant_dermatitis_images_2',
#   'contact_irritant_dermatitis_images_3',
#   'contact_irritant_dermatitis_images_4',
#   'contact_irritant_dermatitis_images_5',
#   'contact_leukoderma_0',
#   'contact_reactions_to_cosmetics_0',
#   'contact_reactions_to_cosmetics_1',
#   'contact_reactions_to_cosmetics_2',
#   'contact_reactions_to_cosmetics_3',
#   'contact_reactions_to_lanolin_0',
#   'contact_reactions_to_lanolin_1',
#   'contact_reactions_to_lanolin_2',
#   'contact_reactions_to_lanolin_3',
#   'contact_reactions_to_lanolin_4',
#   'contact_reactions_to_lipsticks_and_other_lipcare_products_0',
#   'contact_reactions_to_toothpaste_and_other_oral_hygiene_products_0',
#   'contact_reactions_to_toothpaste_and_other_oral_hygiene_products_1',
#   'contact_stomatitis_0',
#   'contact_stomatitis_1',
#   'contact_urticaria_0',
#   'contact_urticaria_1',
#   'contact_urticaria_2',
#   'contact_urticaria_3',
#   'contact_urticaria_4',
#   'contact_urticaria_5',
#   'cow_parsnip_hogweed_0',
#   'cow_parsnip_hogweed_1',
#   'cow_parsnip_hogweed_2',
#   'cow_parsnip_hogweed_3',
#   'cow_parsnip_hogweed_4',
#   'cow_parsnip_hogweed_5',
#   'cutaneous_adverse_effects_of_alcohol_0',
#   'cutaneous_adverse_effects_of_alcohol_1',
#   'cutaneous_adverse_effects_of_alcohol_2',
#   'cutaneous_adverse_effects_of_alcohol_3',
#   'cutaneous_adverse_effects_of_alcohol_4',
#   'cutaneous_adverse_effects_of_alcohol_5',
#   'cutaneous_adverse_effects_of_alcohol_6',
#   'cutaneous_adverse_effects_of_alcohol_7',
#   'cutaneous_adverse_effects_of_alcohol_8',
#   'cutaneous_adverse_effects_of_alcohol_9',
#   'cutaneous_adverse_effects_of_alcohol_10',
#   'cutaneous_adverse_effects_of_alcohol_11',
#   'cutaneous_adverse_effects_of_alcohol_12',
#   'cutaneous_adverse_effects_of_alcohol_13',
#   'cutaneous_adverse_effects_of_alcohol_14',
#   'cutaneous_adverse_effects_of_alcohol_15',
#   'cutaneous_adverse_effects_of_alcohol_16',
#   'cutaneous_adverse_effects_of_alcohol_17',
#   'cutaneous_adverse_effects_of_alcohol_18',
#   'cutaneous_adverse_effects_of_alcohol_19',
#   'cutaneous_adverse_effects_of_alcohol_20',
#   'cutaneous_adverse_effects_of_alcohol_21',
#   'cutaneous_adverse_effects_of_alcohol_22',
#   'cutaneous_adverse_effects_of_alcohol_23',
#   'cutaneous_adverse_effects_of_alcohol_24',
#   'cutaneous_adverse_effects_of_alcohol_25',
#   'cutaneous_adverse_effects_of_alcohol_26',
#   'cutaneous_adverse_effects_of_alcohol_27',
#   'cutaneous_adverse_effects_of_alcohol_28',
#   'cutaneous_adverse_effects_of_alcohol_29',
#   'cutaneous_adverse_effects_of_alcohol_30',
#   'cutaneous_adverse_effects_of_alcohol_31',
#   'cutaneous_adverse_effects_of_alcohol_32',
#   'cutaneous_adverse_effects_of_alcohol_33',
#   'cutaneous_adverse_effects_of_alcohol_34',
#   'cutaneous_adverse_effects_of_alcohol_35',
#   'cutaneous_adverse_effects_of_alcohol_36',
#   'cutaneous_adverse_effects_of_alcohol_37',
#   'cutaneous_adverse_effects_of_alcohol_38',
#   'cutaneous_adverse_effects_of_alcohol_39',
#   'cutaneous_adverse_effects_of_anticonvulsant_drugs_0',
#   'cutaneous_adverse_effects_of_anticonvulsant_drugs_1',
#   'cutaneous_adverse_effects_of_anticonvulsant_drugs_2',
#   'cutaneous_adverse_effects_of_anticonvulsant_drugs_3',
#   'cutaneous_adverse_effects_of_anticonvulsant_drugs_4',
#   'cutaneous_adverse_effects_of_anticonvulsant_drugs_5',
#   'cutaneous_adverse_effects_of_anticonvulsant_drugs_6',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_0',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_1',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_2',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_3',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_4',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_5',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_6',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_7',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_8',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_9',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_10',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_11',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_12',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_13',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_14',
#   'cutaneous_adverse_effects_of_antimelanoma_therapies_15',
#   'cutaneous_adverse_effects_of_checkpoint_inhibitors_0',
#   'cutaneous_adverse_effects_of_checkpoint_inhibitors_1',
#   'cutaneous_adverse_effects_of_checkpoint_inhibitors_2',
#   'cutaneous_adverse_effects_of_checkpoint_inhibitors_3',
#   'cutaneous_adverse_effects_of_targeted_anticancer_therapies_0',
#   'cutaneous_adverse_effects_of_targeted_anticancer_therapies_1',
#   'cutaneous_adverse_effects_of_targeted_anticancer_therapies_2',
#   'cutaneous_adverse_effects_of_targeted_anticancer_therapies_3',
#   'cutaneous_adverse_effects_of_targeted_anticancer_therapies_4',
#   'cutaneous_adverse_effects_of_targeted_anticancer_therapies_5',
#   'cutaneous_adverse_reactions_to_antibiotics_0',
#   'cutaneous_adverse_reactions_to_antibiotics_1',
#   'cutaneous_adverse_reactions_to_antibiotics_2',
#   'cutaneous_adverse_reactions_to_antibiotics_3',
#   'cutaneous_adverse_reactions_to_antibiotics_4',
#   'cutaneous_adverse_reactions_to_antibiotics_5',
#   'cutaneous_adverse_reactions_to_antibiotics_6',
#   'cutaneous_adverse_reactions_to_antibiotics_7',
#   'cutaneous_adverse_reactions_to_antibiotics_8',
#   'cutaneous_adverse_reactions_to_antibiotics_9',
#   'cutaneous_adverse_reactions_to_antibiotics_10',
#   'cutaneous_adverse_reactions_to_antibiotics_11',
#   'cutaneous_adverse_reactions_to_antibiotics_12',
#   'cutaneous_adverse_reactions_to_antibiotics_13',
#   'cutaneous_adverse_reactions_to_antibiotics_14',
#   'cutaneous_adverse_reactions_to_antibiotics_15',
#   'cutaneous_adverse_reactions_to_antibiotics_16',
#   'cutaneous_adverse_reactions_to_antibiotics_17',
#   'cutaneous_adverse_reactions_to_antibiotics_18',
#   'cutaneous_adverse_reactions_to_calcineurin_inhibitors_0',
#   'cutaneous_adverse_reactions_to_calcineurin_inhibitors_1',
#   'cutaneous_adverse_reactions_to_calcineurin_inhibitors_2',
#   'cutaneous_adverse_reactions_to_calcineurin_inhibitors_3',
#   'cutaneous_adverse_reactions_to_calcineurin_inhibitors_4',
#   'cutaneous_adverse_reactions_to_calcineurin_inhibitors_5',
#   'cutaneous_adverse_reactions_to_calcineurin_inhibitors_6',
#   'cutaneous_adverse_reactions_to_calcineurin_inhibitors_7',
#   'cutaneous_adverse_reactions_to_calcineurin_inhibitors_8',
#   'cutaneous_adverse_reactions_to_calcineurin_inhibitors_9',
#   'cutaneous_effects_of_drugs_of_abuse_0',
#   'cutaneous_toxicity_from_fish_ingestion_0',
#   'cutaneous_toxicity_from_fish_ingestion_1',
#   'cutaneous_toxicity_from_fish_ingestion_2',
#   'daffodil_0',
#   'daffodil_1',
#   'daffodil_2',
#   'dandelion_0',
#   'dermatitis_artefacta_0',
#   'dermatitis_artefacta_1',
#   'dermatitis_artefacta_2',
#   'dermatitis_artefacta_3',
#   'dermatophytide_reactions_0',
#   'dermatophytide_reactions_1',
#   'dermatophytide_reactions_2',
#   'dermatophytide_reactions_3',
#   'dermatophytide_reactions_4',
#   'dermatophytide_reactions_5',
#   'dermatophytide_reactions_6',
#   'dermographism_0',
#   'dermographism_1',
#   'dermographism_2',
#   'dermographism_3',
#   'dermographism_4',
#   'dermographism_5',
#   'dermographism_6',
#   'dermographism_7',
#   'dermographism_8',
#   'dermographism_9',
#   'dermographism_images_0',
#   'dermographism_images_1',
#   'dermographism_images_2',
#   'dermographism_images_3',
#   'dermographism_images_4',
#   'dermographism_images_5',
#   'dermographism_images_6',
#   'dermographism_images_7',
#   'dermographism_images_8',
#   'dermographism_images_9',
#   'dermographism_images_10',
#   'dermographism_images_11',
#   'dermographism_images_12',
#   'dermographism_images_13',
#   'dermographism_images_14',
#   'dogtooth_violet_0',
#   'dogtooth_violet_1',
#   'drug_eruptions_0',
#   'drug_hypersensitivity_syndrome_0',
#   'drug_hypersensitivity_syndrome_1',
#   'drug_hypersensitivity_syndrome_2',
#   'drug_hypersensitivity_syndrome_3',
#   'drug_induced_dermatomyositis_0',
#   'drug_induced_dermatomyositis_1',
#   'drug_induced_dermatomyositis_2',
#   'drug_induced_dermatomyositis_3',
#   'drug_induced_hyperhidrosis_0',
#   'drug_induced_hyperhidrosis_1',
#   'drug_induced_hyperhidrosis_2',
#   'drug_induced_immunosuppression_0',
#   'drug_induced_immunosuppression_1',
#   'drug_induced_immunosuppression_2',
#   'drug_induced_immunosuppression_3',
#   'drug_induced_immunosuppression_4',
#   'drug_induced_immunosuppression_5',
#   'drug_induced_immunosuppression_6',
#   'drug_induced_immunosuppression_7',
#   'drug_induced_immunosuppression_8',
#   'drug_induced_lupus_erythematosus_0',
#   'drug_induced_lupus_erythematosus_1',
#   'drug_induced_lupus_erythematosus_2',
#   'drug_induced_lupus_erythematosus_3',
#   'drug_induced_lupus_erythematosus_4',
#   'drug_induced_lupus_erythematosus_5',
#   'drug_induced_lupus_erythematosus_6',
#   'drug_induced_lupus_erythematosus_7',
#   'drug_induced_lupus_erythematosus_8',
#   'drug_induced_lupus_erythematosus_9',
#   'drug_induced_nail_disease_0',
#   'drug_induced_nail_disease_1',
#   'drug_induced_nail_disease_2',
#   'drug_induced_nail_disease_3',
#   'drug_induced_nail_disease_4',
#   'drug_induced_nummular_dermatitis_0',
#   'drug_induced_nummular_dermatitis_1',
#   'drug_induced_nummular_dermatitis_2',
#   'drug_induced_nummular_dermatitis_3',
#   'drug_induced_pemphigus_0',
#   'drug_induced_pemphigus_1',
#   'drug_induced_pemphigus_2',
#   'drug_induced_pemphigus_3',
#   'drug_induced_photosensitivity_0',
#   'drug_induced_photosensitivity_1',
#   'drug_induced_photosensitivity_2',
#   'drug_induced_pigmentation_0',
#   'drug_induced_pigmentation_1',
#   'drug_induced_pigmentation_2',
#   'drug_induced_pigmentation_3',
#   'drug_induced_pigmentation_4',
#   'drug_induced_pigmentation_5',
#   'drug_induced_pigmentation_6',
#   'drug_induced_pigmentation_7',
#   'drug_induced_pigmentation_8',
#   'drug_induced_pruritus_0',
#   'drug_induced_pruritus_1',
#   'drug_induced_pruritus_2',
#   'drug_induced_pruritus_3',
#   'drug_induced_psoriasis_0',
#   'drug_induced_psoriasis_1',
#   'drug_induced_psoriasis_2',
#   'drug_induced_psoriasis_3',
#   'drug_induced_urticaria_0',
#   'drug_induced_urticaria_1',
#   'drug_induced_urticaria_2',
#   'drug_induced_urticaria_3',
#   'drug_induced_vitiligo_0',
#   'drug_induced_vitiligo_1',
#   'drug_induced_vitiligo_2',
#   'drug_induced_vitiligo_3',
#   'drugs_reported_to_cause_erythroderma_0',
#   'egfr_and_protein_kinase_inhibitors_0',
#   'egfr_and_protein_kinase_inhibitors_1',
#   'egfr_and_protein_kinase_inhibitors_2',
#   'egfr_and_protein_kinase_inhibitors_3',
#   'egfr_and_protein_kinase_inhibitors_4',
#   'egfr_and_protein_kinase_inhibitors_5',
#   'egfr_and_protein_kinase_inhibitors_6',
#   'egfr_and_protein_kinase_inhibitors_7',
#   'egfr_and_protein_kinase_inhibitors_8',
#   'electrical_burn_0',
#   'english_ivy_0',
#   'english_ivy_1',
#   'english_ivy_2',
#   'erythema_ab_igne_0',
#   'erythema_ab_igne_1',
#   'erythema_ab_igne_2',
#   'erythema_ab_igne_3',
#   'erythema_ab_igne_4',
#   'exercise_induced_anaphylaxis_0',
#   'exercise_induced_anaphylaxis_1',
#   'exercise_induced_anaphylaxis_2',
#   'exercise_induced_anaphylaxis_3',
#   'exercise_induced_vasculitis_0',
#   'exercise_induced_vasculitis_1',
#   'exercise_induced_vasculitis_2',
#   'exercise_induced_vasculitis_3',
#   'exercise_induced_vasculitis_4',
#   'eyelid_contact_dermatitis_0',
#   'eyelid_contact_dermatitis_1',
#   'eyelid_contact_dermatitis_2',
#   'eyelid_contact_dermatitis_3',
#   'fibreglass_dermatitis_0',
#   'fibreglass_dermatitis_1',
#   'fibreglass_dermatitis_2',
#   'fibreglass_dermatitis_3',
#   'fibreglass_dermatitis_4',
#   'fibreglass_dermatitis_5',
#   'fig_0',
#   'fig_1',
#   'fig_2',
#   'fig_3',
#   'fig_4',
#   'fig_5',
#   'fig_6',
#   'fixed_drug_eruption_0',
#   'fixed_drug_eruption_1',
#   'fixed_drug_eruption_2',
#   'fixed_drug_eruption_3',
#   'fixed_drug_eruption_4',
#   'fixed_drug_eruption_5',
#   'fixed_drug_eruption_6',
#   'fixed_drug_eruption_7',
#   'fixed_drug_eruption_8',
#   'fixed_drug_eruption_9',
#   'flagellate_erythema_0',
#   'flagellate_erythema_1',
#   'flagellate_erythema_2',
#   'flagellate_erythema_3',
#   'follicular_eruptions_due_to_drugs_0',
#   'follicular_eruptions_due_to_drugs_1',
#   'follicular_eruptions_due_to_drugs_2',
#   'food_additives_0',
#   'food_additives_and_e_numbers_0',
#   'food_allergy_0',
#   'food_allergy_1',
#   'food_allergy_2',
#   'food_allergy_3',
#   'foreign_body_granuloma_0',
#   'foreign_body_granuloma_1',
#   'foreign_body_granuloma_2',
#   'foreign_body_granuloma_3',
#   'formaldehyde_allergy_0',
#   'formaldehyde_allergy_1',
#   'fragrance_allergy_0',
#   'fragrance_allergy_1',
#   'fragrance_allergy_2',
#   'fragrance_allergy_3',
#   'fragrance_allergy_4',
#   'fragrance_allergy_5',
#   'fragrance_allergy_6',
#   'fragrance_allergy_7',
#   'fragrance_allergy_8',
#   'fragrance_allergy_9',
#   'fragrance_allergy_10',
#   'fragrance_allergy_11',
#   'fragrance_allergy_12',
#   'fragrance_mix_allergy_0',
#   'fragrance_mix_allergy_1',
#   'fragrance_mix_allergy_2',
#   'fragrance_mix_allergy_3',
#   'fragrances_and_perfumes_0',
#   'fragrances_and_perfumes_1',
#   'fragrances_and_perfumes_2',
#   'fragrances_and_perfumes_3',
#   'fragrances_and_perfumes_4',
#   'fragrances_and_perfumes_5',
#   'fragrances_and_perfumes_6',
#   'fragrances_and_perfumes_7',
#   'fragrances_and_perfumes_8',
#   'fragrances_and_perfumes_9',
#   'fragrances_and_perfumes_10',
#   'fragrances_and_perfumes_11',
#   'fragrances_and_perfumes_12',
#   'french_marigold_0',
#   'frostbite_0',
#   'garlic_0',
#   'garlic_1',
#   'grevillea_0',
#   'grevillea_1',
#   'grevillea_2',
#   'grevillea_3',
#   'halogenoderma_0',
#   'hand_foot_syndrome_0',
#   'hand_foot_syndrome_1',
#   'hand_foot_syndrome_2',
#   'hand_foot_syndrome_3',
#   'heat_urticaria_0',
#   'heat_urticaria_1',
#   'house_dust_mite_0',
#   'house_dust_mite_1',
#   'house_dust_mite_2',
#   'hydroa_vacciniforme_0',
#   'hydroa_vacciniforme_1',
#   'hydroa_vacciniforme_2',
#   'hydroa_vacciniforme_3',
#   'hydroa_vacciniforme_4',
#   'hydroa_vacciniforme_5',
#   'hydroa_vacciniforme_6',
#   'hypergranulotic_dyscornification_0',
#   'hypergranulotic_dyscornification_1',
#   'hypergranulotic_dyscornification_pathology_0',
#   'hypergranulotic_dyscornification_pathology_1',
#   'hypergranulotic_dyscornification_pathology_2',
#   'hypergranulotic_dyscornification_pathology_3',
#   'hypergranulotic_dyscornification_pathology_4',
#   'hypergranulotic_dyscornification_pathology_5',
#   'hypergranulotic_dyscornification_pathology_6',
#   'immunotherapy_for_allergic_diseases_0',
#   'insect_bite_images_0',
#   'insect_bite_images_1',
#   'insect_bite_images_2',
#   'insect_bite_images_3',
#   'insect_bite_images_4',
#   'insect_bite_images_5',
#   'insect_bite_images_6',
#   'insect_bite_images_7',
#   'insect_bite_images_8',
#   'insect_bite_images_9',
#   'insect_bite_images_10',
#   'insect_bite_images_11',
#   'insect_bite_images_12',
#   'insect_bite_images_13',
#   'insect_bite_images_14',
#   'insect_bite_images_15',
#   'insect_bite_images_16',
#   'insect_bite_images_17',
#   'insect_bite_images_18',
#   'insect_bite_images_19',
#   'insect_bite_images_20',
#   'insect_bite_images_21',
#   'insect_bite_images_22',
#   'insect_bite_images_23',
#   'insect_bite_images_24',
#   'insect_bite_images_25',
#   'insect_bite_images_26',
#   'insect_bite_images_27',
#   'irritant_contact_dermatitis_0',
#   'irritant_contact_dermatitis_1',
#   'irritant_contact_dermatitis_2',
#   'irritant_contact_dermatitis_3',
#   'irritant_contact_dermatitis_4',
#   'irritant_contact_dermatitis_5',
#   'irritant_contact_dermatitis_6',
#   'irritant_contact_dermatitis_7',
#   'irritant_contact_dermatitis_8',
#   'irritant_contact_dermatitis_9',
#   'irritant_contact_dermatitis_10',
#   'irritant_contact_dermatitis_11',
#   'irritant_contact_dermatitis_12',
#   'jewellery_allergy_0',
#   'jewellery_allergy_1',
#   'kava_dermopathy_0',
#   'kava_dermopathy_1',
#   'kava_dermopathy_2',
#   'kava_dermopathy_3',
#   'kava_dermopathy_4',
#   'keloid_and_hypertrophic_scar_0',
#   'keloid_and_hypertrophic_scar_1',
#   'keloid_and_hypertrophic_scar_2',
#   'keloid_and_hypertrophic_scar_3',
#   'keloid_and_hypertrophic_scar_4',
#   ...],
#  'embeddings': array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.03022753,  0.01889128,  0.0650273 , ...,  0.16998789,
#           0.06037932, -0.06911249],
#         [ 0.21143579, -0.12780297,  0.22947049, ...,  0.25358191,
#          -0.19496617,  0.09831563],
#         ...,
#         [ 0.05726408, -0.07835034,  0.13098353, ...,  0.24872005,
#          -0.13554974,  0.08722917],
#         [ 0.04012229,  0.03940468,  0.09829734, ...,  0.17530449,
#           0.09678497, -0.07183577],
#         [ 0.11745498, -0.14233939,  0.01094962, ...,  0.19071992,
#           0.15531677, -0.24855171]]),
#  'documents': None,
#  'uris': None,
#  'data': None,
#  'metadatas': None,
#  'included': [<IncludeEnum.embeddings: 'embeddings'>]}

# %%
def search_skin_disease(query_text=None, query_image=None, top_k=5):
    if query_image:
        image_embedding = get_image_embedding(query_image)
        results = collection.query(image_embedding, n_results=top_k)
    elif query_text:
        text_embedding = get_text_embedding(query_text)
        results = collection.query(text_embedding, n_results=top_k)
    else:
        raise ValueError("Provide either an image or a text description.")

    return results["metadatas"]

# # Example Search
# retrieved_cases = search_skin_disease(query_image="image_11.jpeg")
# print(retrieved_cases)

# %%
# len(get_image_embedding("image_11.jpeg"))

# %%
# generate_image_caption("image_11.jpeg")

# %%
import huggingface_hub
huggingface_hub.login("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")

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import BitsAndBytesConfig
import torch

model_name = "mistralai/Mistral-7B-Instruct-v0.3"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Enable 4-bit quantization to reduce memory usage
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,  # Use 4-bit precision to reduce GPU RAM usage
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,  # Improves precision
    bnb_4bit_quant_type="nf4"  # Optimized quantization
)

# Load model with quantization
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto"  # Automatically distributes to available GPU
)

print("Model loaded successfully!")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Model loaded successfully!

# %%
# Load Mistral 7B Instruct Model
# model_name = "mistralai/Mistral-7B-Instruct-v0.1"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16,
#     device_map={"": "cpu"},  # Forces CPU execution
#     offload_folder="offload")

def generate_diagnosis(retrieved_cases, user_query):
    # context = "\n".join([f"Disease: {case['disease']}\nSymptoms: {case['symptoms']}" for case in retrieved_cases])
    context = "\n".join([
        f"Disease: {case[0]['disease']}\nSymptoms: {case[0]['symptoms']}"
        for case in retrieved_cases  # Accessing the metadata list
    ])

    prompt = f"""
    A user has uploaded an image of a skin condition and described their symptoms.
    Based on the following medical records, provide a possible diagnosis.

    Medical Cases:
    {context}

    User Query:
    {user_query}

    Analyze the context carefully to extract Remedies of the disease.
    If it can'nt be found out from the context,advice the pateint to consult with a dermatologist.
    Diagnosis and Recommendations:
    """

    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    outputs = model.generate(**inputs, max_length=500)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
# Example usage
query_text = "I have got an itchy rash and blisters at the site of my skin "
retrieved_cases = search_skin_disease(query_text=query_text, query_image="/content/data/acne_due_to_medicine/images/image_10.jpeg")
diagnosis = generate_diagnosis(retrieved_cases, query_text)
print(diagnosis)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#     A user has uploaded an image of a skin condition and described their symptoms.
#     Based on the following medical records, provide a possible diagnosis.
#
#     Medical Cases:
#     Disease: acne_due_to_medicine
# Symptoms: 1. Redness
#     2. Swelling
#     3. Pain
#     4. Whiteheads
#     5. Blackheads
#
#     User Query:
#     I have got an itchy rash and blisters at the site of my skin
#
#     Analyze the context carefully to extract Remedies of the disease.
#     If it can'nt be found out from the context,advice the pateint to consult with a dermatologist.
#     Diagnosis and Recommendations:
#     1. Based on the symptoms provided, it seems like the user might have a skin condition other than acne.
#     2. To confirm the diagnosis, it is recommended that the user consults with a dermatologist for a proper examination.
#     3. If the condition is indeed acne, it could be due to a reaction to certain medications. In this case, the user should consider discontinuing the medication and seeking an alternative treatment.
#     4. If the condition is not acne, the user should follow the treatment plan prescribed by their dermatologist.
#     5. In either case, it is important for the user to maintain good hygiene and avoid picking at the affected area to prevent further irritation or infection.
